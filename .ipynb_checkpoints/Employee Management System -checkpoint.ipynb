# %%
class Employee:
    def __init__(self, name,salary):
        self.name=name
        self.salary=salary
    def display(self):
        print("Name: ",self.name)
        print("Salary: ",self.salary)
class Manager(Employee):
    def __init__(self,name,salary,dept):
        super().__init__(name,salary)
        self.dept=dept
    def display(self):
        print("Name: ",self.name)
        print("Salary: ", self.salary)
        print("Department: ",self.dept)
m=Manager("Aftab",200000,"IT")
m.display()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 16
#      14         print("Salary: ", self.salary)
#      15         print("Department: ",self.dept)
# ---> 16 m=Manager("Aftab",200000,"IT")
#      17 m.display()
#
# Cell In[1], line 10, in Manager.__init__(self, name, salary, dept)
#       9 def __init__(self,name,salary,dept):
# ---> 10     super.__init__(name,salary)
#      11     self.dept=dept
#
# TypeError: descriptor '__init__' requires a 'super' object but received a 'str'
